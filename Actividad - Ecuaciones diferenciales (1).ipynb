# %% [markdown]
# # Actividad - Ecuaciones diferenciales

# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import scipy as sp
from scipy.integrate import solve_ivp,odeint

# %% [markdown]
# 1. Resolver numéricamente con `solve_ivp` la siguiente ecuación diferencial:
# $$\frac{dx}{dt}=\frac{x}{t+1}$$

# %%
def sol (x,t):
    return x/(t+1)
ts=[0, 50]
x0=np.array([1])
x2= solve_ivp(sol,ts,x)

# %%
x2
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 68
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 1.00000000e-04, 1.10000000e-03, 1.11000000e-02,
#        1.11100000e-01, 1.11110000e+00, 4.47902025e+00, 7.84694051e+00,
#        1.76778114e+01, 4.57078228e+01, 5.00000000e+01])
#  t_events: None
#         y: array([[ 2.        ,  2.        ,  2.0000002 ,  2.00002053,  2.0020565 ,
#          2.19914717,  4.38797812,  7.39893886, 16.92881482, 44.8050683 ,
#         49.08891309]])
#  y_events: None

# %%
plt.plot(x2.t,x2.y[0, :])
plt.grid()

# %% [markdown]
# Grafique con condición inicial $x_0 = 2$

# %%
solve_ivp?

# %%
def sol1 (x,t):
    return x/(t+1)
ts=[0, 50]
x0=np.array([2])
X3= solve_ivp(sol1,ts,x)

# %%
plt.plot(X3.t,X3.y[0, :])
plt.grid()

# %% [markdown]
# 2. Encuentre la solución numérica para un oscilador armónico simple:
#
# $$
# \frac{d^2 x}{dt^2} +  \omega_{0}^2 x = 0.
# $$
# Donde $x_0=0.5$, $\dot{x}_0=0.1$ y $\omega_0=3$.

# %% [markdown]
# 2.1 Defina una función, cuyos argumentos de entrada sean:
#
#
# 1. el tiempo $t$,
# 2. el arreglo $[x,\dot{x}]$.
#
# Y la salida:
#
# 1. el arreglo $[\dot{x},\ddot{x}]$.
#
#   Considerando el argumento de la frecuencia natural $\omega_0$ debe ser una variable global.

# %%
def posicion(t,w0=3):
    A=0.5
    B=0.1
    return A*np.cos(w0*t)+B*np.sin(w0*t)

def velocidad(t,w0=3):
    A=0.5
    B=0.1
    return w0*(-A*np.cos(w0*t)+B*np.sin(w0*t))

# %%
t=np.linspace(0,10,1000)
w0=3
plt.figure
plt.plot(t,posicion(t,w0), label="Posicion")
plt.plot(t,velocidad(t,w0), label="Velocidad")
plt.legend(loc="best")
plt.grid()

# %%
from ipywidgets import *

# %%
def posicion(t,w0,x0,v0):
    A=x0
    B=v0/w0
    return A*np.cos (w0*t) + B*np.sin(w0*t)

def grafico(t=0,l=1,X0=0.5,v0=0.1):
    g=9.81
    w0=np.sqrt(g/1)
    x=posicion(t,w0,x0,v0)
    print(X)
    x=1*np.sin(x)
    y=-1*np.cos(x)
    fig=plt.figure()
    ax=fig.add_subplot (1,1,1)
    ax.plot([-1.1,1.1],[0,0],"k",lw= 4)
    ax.plot(0,0,"xr",ms=20)
    ax.plot (x,y,"ob",ms=20)
    ax.plot ([0,x],[0,y],"b",lw=4)
    plt.xlim([-1.1,1.1])
    plt.ylim([-1.1,0.11])
    
interact(grafico,t=(0,10,0.1),l=fixed(1),x=fixed(0.5),v0=fixed(0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=10.0), FloatSlider(value=0.5, description='X…
# <function __main__.grafico(t=0, l=1, X0=0.5, v0=0.1)>

# %%
def sol(t,x):
    return np.array ([X[1], -(w0**2)*X[0]])
W0=3
tspan=[0,50]
X=np.array([0.5,0.1])
sol=solve_ivp(dx,tspan,X,max_step-0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 6>()
#       4 tspan=[0,50]
#       5 X=np.array([0.5,0.1])
# ----> 6 sol=solve_ivp(dx,tspan,X,max_step-0.01)
#
# NameError: name 'dx' is not defined

# %% [markdown]
# Grafique

# %%
plt.plot(sol.t,sol.y[0,:])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 plt.plot(sol.t,sol.y[0,:])
#       2 plt.grid()
#
# AttributeError: 'function' object has no attribute 't'

# %% [markdown]
# Asigne a los parámetros de la solución analítica $C_1=x_0$ y $C_2=\frac{\dot{x}_0}{\omega_0}$.

# %%
def pos(t,w0,x0,v0):
    return x0*np.cos(w0*t)+(v0/w0)*np.sin(w0*t)
sol_a=posicion(sol_x.t,w0,0.5,0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 3>()
#       1 def pos(t,w0,x0,v0):
#       2     return x0*np.cos(w0*t)+(v0/w0)*np.sin(w0*t)
# ----> 3 sol_a=posicion(sol_x.t,w0,0.5,0.1)
#
# NameError: name 'sol_x' is not defined

# %% [markdown]
# Redefina la función para graficarla (con la palabra reservada ***def***) en un intervalo de tiempo de 0 a 10 segundos. Comparela en un mismo grafico con la solución numérica obtenida.

# %%
plt.figure()
plt.plot(sol_x.t,sol_a,lw=5)
plt.plot(sol_x.t,sol_x.y[0,:],"r")
plt.grid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 2>()
#       1 plt.figure()
# ----> 2 plt.plot(sol_x.t,sol_a,lw=5)
#       3 plt.plot(sol_x.t,sol_x.y[0,:],"r")
#       4 plt.grid
#
# NameError: name 'sol_x' is not defined
